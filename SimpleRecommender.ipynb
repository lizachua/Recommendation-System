# %% [markdown]
# # Simple Recommender

# %% [markdown]
# ### A simple movie recommender system based on weighted movie ratings (from datacamp tutorial)

# %% [markdown]
# To start, we'll download data sets from Full MovieLens Dataset and load datasets. The small dataset is used here, which consist of 100,000 ratings and 3,600 tag applications applied to 9,000 movies by 600 users.

# %%
#import libraries

import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
movies = pd.read_csv('ml-latest-small/movies.csv')
ratings.head()
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# Next, we'll calculate the average ratings of each movie and the number of ratings received for each movie

# %%
ratings_group = ratings[['movieId','rating']]
ratings_group = ratings_group.groupby(['movieId']).agg(vote_avg=("rating","mean"), vote_count=("rating","count"))
ratings_group
# Out:
#          vote_avg  vote_count
# movieId
# 1        3.920930         215
# 2        3.431818         110
# 3        3.259615          52
# 4        2.357143           7
# 5        3.071429          49
# ...           ...         ...
# 193581   4.000000           1
# 193583   3.500000           1
# 193585   3.500000           1
# 193587   3.500000           1
# 193609   4.000000           1
#
# [9724 rows x 2 columns]

# %% [markdown]
# Combine both movies and ratings dataframe to one single dataframe

# %%
movies_ratings = pd.merge(movies,ratings_group,on=['movieId'])
movies_ratings
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  vote_avg  vote_count
# 0     Adventure|Animation|Children|Comedy|Fantasy  3.920930         215
# 1                      Adventure|Children|Fantasy  3.431818         110
# 2                                  Comedy|Romance  3.259615          52
# 3                            Comedy|Drama|Romance  2.357143           7
# 4                                          Comedy  3.071429          49
# ...                                           ...       ...         ...
# 9719              Action|Animation|Comedy|Fantasy  4.000000           1
# 9720                     Animation|Comedy|Fantasy  3.500000           1
# 9721                                        Drama  3.500000           1
# 9722                             Action|Animation  3.500000           1
# 9723                                       Comedy  4.000000           1
#
# [9724 rows x 5 columns]

# %% [markdown]
# Now, we'll generate a weight rating for each movie based on the IMDB formula:
#
# ##### Weighted Rating = (m/(v+m))*R + (m/(v+m))*C
#
# where,
#
# v is the number of votes for the movie;
# m is the minimum votes required to be listed in the chart;
# R is the average rating of the movie;
# C is the mean vote across the whole report.
#
# We have values to R (vote_avg) and v (vote_count). We will need to determine the values of C and m. In this project, m is set as the 90th percentile,  where we consider the top 10% of the movies in terms of the number of votes garnered.

# %%
#Determine value of C
C = movies_ratings['vote_avg'].mean()
C
# Out:
# 3.262448274810963

# %% [markdown]
# It is observed that the mean rating acorss all movies is around 3.26 on a scale of 5

# %% [markdown]
# Next, we calculate the number of votes, m, received by a movie in the 90th percentile

# %%
#Determine value of m
m = movies_ratings['vote_count'].quantile(0.90)
m
# Out:
# 27.0

# %% [markdown]
# The top 10% of the movies in terms of numer of votes garnered must receive at least 27 vote counts. With this, we can generate a new dataframe with movies having at least 27 vote counts.

# %%
movies_ratings_filtered = movies_ratings.copy().loc[movies_ratings['vote_count'] >= m]
movies_ratings_filtered.shape
# Out:
# (976, 5)

# %% [markdown]
# There are 976 movies that makes the mark to the minum number of vote counts, about 10% of all the movies in the list

# %% [markdown]
# Now, we can calculate the weighted rating for each movie

# %%
#Define a function to calculate the weighted rating
def weighted_rating(x, C, m):
    R = x['vote_avg']
    v = x['vote_count']

    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
#Define a new column score for the weighted ratings calculated
movies_ratings_filtered['score'] = weighted_rating(x=movies_ratings_filtered,C=C,m=m)
movies_ratings_filtered
# Out:
#       movieId                                title  \
# 0           1                     Toy Story (1995)
# 1           2                       Jumanji (1995)
# 2           3              Grumpier Old Men (1995)
# 4           5   Father of the Bride Part II (1995)
# 5           6                          Heat (1995)
# ...       ...                                  ...
# 8861   134130                   The Martian (2015)
# 8882   134853                    Inside Out (2015)
# 8972   139385                  The Revenant (2015)
# 9205   152081                      Zootopia (2016)
# 9415   166528  Rogue One: A Star Wars Story (2016)
#
#                                                  genres  vote_avg  vote_count  \
# 0           Adventure|Animation|Children|Comedy|Fantasy  3.920930         215
# 1                            Adventure|Children|Fantasy  3.431818         110
# 2                                        Comedy|Romance  3.259615          52
# 4                                                Comedy  3.071429          49
# 5                                 Action|Crime|Thriller  3.946078         102
# ...                                                 ...       ...         ...
# 8861                             Adventure|Drama|Sci-Fi  4.000000          48
# 8882  Adventure|Animation|Children|Comedy|Drama|Fantasy  3.813953          43
# 8972                                    Adventure|Drama  3.903226          31
# 9205         Action|Adventure|Animation|Children|Comedy  3.890625          32
# 9415                    Action|Adventure|Fantasy|Sci-Fi  3.925926          27
#
#          score
# 0     3.847463
# 1     3.398439
# 2     3.260584
# 4     3.139291
# 5     3.802993
# ...        ...
# 8861  3.734481
# 8882  3.601230
# 8972  3.604933
# 9205  3.603154
# 9415  3.594187
#
# [976 rows x 6 columns]

# %%
#Get the top 20 movies
movies_ratings_filtered = movies_ratings_filtered.sort_values('score',ascending=False)
movies_ratings_filtered.head(20)
# Out:
#       movieId                                              title  \
# 277       318                   Shawshank Redemption, The (1994)
# 659       858                              Godfather, The (1972)
# 2224     2959                                  Fight Club (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 46         50                         Usual Suspects, The (1995)
# 257       296                                Pulp Fiction (1994)
# 461       527                            Schindler's List (1993)
# 1938     2571                                 Matrix, The (1999)
# 897      1196  Star Wars: Episode V - The Empire Strikes Back...
# 314       356                                Forrest Gump (1994)
# 899      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 6693    58559                            Dark Knight, The (2008)
# 921      1221                     Godfather: Part II, The (1974)
# 510       593                   Silence of the Lambs, The (1991)
# 898      1197                         Princess Bride, The (1987)
# 913      1213                                  Goodfellas (1990)
# 6298    48516                               Departed, The (2006)
# 1733     2329                          American History X (1998)
# 602       750  Dr. Strangelove or: How I Learned to Stop Worr...
# 895      1193             One Flew Over the Cuckoo's Nest (1975)
#
#                                        genres  vote_avg  vote_count     score
# 277                               Crime|Drama  4.429022         317  4.337460
# 659                               Crime|Drama  4.289062         192  4.162494
# 2224              Action|Crime|Drama|Thriller  4.272936         218  4.161576
# 224                   Action|Adventure|Sci-Fi  4.231076         251  4.137000
# 46                     Crime|Mystery|Thriller  4.237745         204  4.123749
# 257               Comedy|Crime|Drama|Thriller  4.197068         307  4.121515
# 461                                 Drama|War  4.225000         220  4.119782
# 1938                   Action|Sci-Fi|Thriller  4.192446         278  4.110118
# 897                   Action|Adventure|Sci-Fi  4.215640         211  4.107505
# 314                  Comedy|Drama|Romance|War  4.164134         329  4.095747
# 899                          Action|Adventure  4.207500         200  4.095093
# 6693                  Action|Crime|Drama|IMAX  4.238255         149  4.088557
# 921                               Crime|Drama  4.259690         129  4.087090
# 510                     Crime|Horror|Thriller  4.161290         279  4.081981
# 898   Action|Adventure|Comedy|Fantasy|Romance  4.232394         142  4.077433
# 913                               Crime|Drama  4.250000         126  4.075726
# 6298                     Crime|Drama|Thriller  4.252336         107  4.052881
# 1733                              Crime|Drama  4.217054         129  4.051834
# 602                                Comedy|War  4.268041          97  4.049081
# 895                                     Drama  4.203008         133  4.044288
